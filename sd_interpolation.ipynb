# %% [markdown]
# # Install Dependencies

# %%
# !pip install -q condacolab
import condacolab

condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:08
# 🔁 Restarting kernel...

# %%
# !git clone https://github.com/RobBaldauf/ControlNetInterpolation ControlNet
# %cd ControlNet/
# Out:
# Cloning into 'ControlNet'...
# remote: Enumerating objects: 1515, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 1515 (delta 0), reused 2 (delta 0), pack-reused 1512 (from 1)
# Receiving objects: 100% (1515/1515), 152.14 MiB | 36.13 MiB/s, done.
# Resolving deltas: 100% (669/669), done.
# /content/ControlNet

# %%
# !mamba env create -f environment.yaml
# Out:
# [+] 0.0s
# [+] 0.1s
# pytorch/linux-64 (..  ⣾  pytorch/linux-64 (check zst)
# [+] 0.0s
# pytorch/noarch (ch..  ⣾  pytorch/noarch (check zst)
# [+] 0.0s
# pkgs/main/linux-64 (check zst)                     Checked  0.1s
# [+] 0.0s
# pkgs/main/noarch (check zst)                       Checked  0.0s
# [+] 0.0s
# pkgs/r/linux-64 (c..  ⣾  pkgs/r/linux-64 (check zst)
# [+] 0.0s
# pkgs/r/noarch (che..  ⣾  pkgs/r/noarch (check zst)
# [+] 0.0s
# pytorch/noarch                                      11.4kB @ 151.4kB/s  0.1s
# pytorch/linux-64                                   217.0kB @   2.5MB/s  0.1s
# [+] 0.1s
# conda-forge/linux-64  ⣾
# pkgs/main/linux-64     2%
# pkgs/main/noarch      ⣾
# pkgs/r/linux-64       ⣾
# pkgs/r/noarch         ⣾  pkgs/main/noarch
# [+] 0.2s
# conda-forge/linux-64   4%
# conda-forge/noarch    ⣾
# pkgs/main/linux-64    96%
# pkgs/r/linux-64       32%
# pkgs/r/noarch          2%pkgs/r/linux-64
# pkgs/main/linux-64
# [+] 0.3s
# conda-forge/linux-64  12%
# ...

# %%
#!huggingface-cli download thibaud/controlnet-sd21 control_v11p_sd21_openpose.ckpt --local-dir models/
# !huggingface-cli download lllyasviel/ControlNet models/control_sd15_openpose.pth --local-dir models/
# !mv models/models/control_sd15_openpose.pth models/
# Out:
# ...
# control_sd15_openpose.pth: 100% 5.71G/5.71G [00:31<00:00, 181MB/s]
# Download complete. Moving file to models/models/control_sd15_openpose.pth
# models/models/control_sd15_openpose.pth

# %%
# !source /usr/local/bin/activate && conda activate control && conda install git pip
# Out:
# Channels:
#  - conda-forge
#  - defaults
#  - pytorch
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/control
#
#   added / updated specs:
#     - git
#     - pip
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aom-3.5.0                  |       h27087fc_0         2.7 MB  conda-forge
#     c-ares-1.33.1              |       heb4867d_0         179 KB  conda-forge
#     ca-certificates-2024.8.30  |       hbcca054_0         155 KB  conda-forge
#     cairo-1.16.0               |    h35add3b_1015         1.1 MB  conda-forge
#     certifi-2024.8.30          |     pyhd8ed1ab_0         160 KB  conda-forge
# ...

# %%
# !source /usr/local/bin/activate && conda activate control && pip install git+https://github.com/openai/CLIP.git
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-vdlay2zt
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-vdlay2zt
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369492 sha256=81117486196661e763051874a9c51b05ec22ede4dd029a61048de43e29efa326
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l6uuhqvt/wheels/ab/4f/3a/5e51521b55997aa6f0690e095c08824219753128ce8d9969a3
# Successfully built clip
# ...

# %%
# !cp /content/drive/MyDrive/interpolation/final_png/ . -r

# %% [markdown]
# # Run inference

# %%
# !source /usr/local/bin/activate && conda activate control && python interpolate_final.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Data shape for DDIM sampling is (1, 4, 96, 96), eta 0.1
# Running DDIM Sampling with 49 timesteps
# DDIM Sampler: 100% 49/49 [00:18<00:00,  2.64it/s]
# Data shape for DDIM sampling is (1, 4, 96, 96), eta 0.1
# Running DDIM Sampling with 49 timesteps
# DDIM Sampler: 100% 49/49 [00:18<00:00,  2.64it/s]
# Data shape for DDIM sampling is (1, 4, 96, 96), eta 0.1
# Running DDIM Sampling with 49 timesteps
# DDIM Sampler: 100% 49/49 [00:18<00:00,  2.64it/s]
# Data shape for DDIM sampling is (1, 4, 96, 96), eta 0.1
# Running DDIM Sampling with 49 timesteps
# DDIM Sampler: 100% 49/49 [00:18<00:00,  2.64it/s]
# Data shape for DDIM sampling is (1, 4, 96, 96), eta 0.1
# Running DDIM Sampling with 49 timesteps
# DDIM Sampler: 100% 49/49 [00:18<00:00,  2.64it/s]
# Data shape for DDIM sampling is (1, 4, 96, 96), eta 0.1
# Running DDIM Sampling with 49 timesteps
# DDIM Sampler: 100% 49/49 [00:18<00:00,  2.64it/s]
# ...

# %%
# !source /usr/local/bin/activate && conda activate control && python interpolate_final_2.py
# Out:
# logging improved.
# No module 'xformers'. Proceeding without it.
# ControlLDM: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# making attention of type 'vanilla' with 512 in_channels
# Downloading: 100% 939k/939k [00:00<00:00, 15.5MB/s]
# Downloading: 100% 512k/512k [00:00<00:00, 10.0MB/s]
# Downloading: 100% 389/389 [00:00<00:00, 2.57MB/s]
# Downloading: 100% 905/905 [00:00<00:00, 6.37MB/s]
# Downloading: 100% 4.41k/4.41k [00:00<00:00, 18.6MB/s]
# Downloading: 100% 1.59G/1.59G [00:23<00:00, 74.3MB/s]
# Loaded model config from [./models/cldm_v15.yaml]
# Processing final_06_final_07
# Downloading: "https://huggingface.co/lllyasviel/ControlNet/resolve/main/annotator/ckpts/body_pose_model.pth" to /content/ControlNet/annotator/ckpts/body_pose_model.pth
#
# 100% 200M/200M [00:00<00:00, 223MB/s]
# ...
